# %%
# Variables & Data Types
study_hours = 5.5       # float
student_name = "Sudha"  # string
passed = True            # boolean
total_students = 30       # int

# Operators
score = study_hours * 10 + 20   # arithmetic
print(score > 50)                # comparison
print(passed and score > 50)     # logical

# Loops
for i in range(1, 6):
    print(f"Study hour {i}: predicted score = {i*10 + 20}")

hours = 0
while hours < 5:
    print(f"Studying... hour {hours+1}")
    hours += 1

# Functions
def predict_score(hours):
    """Simple placeholder logic before we build the real model"""
    return hours * 10 + 20

for h in [1, 2, 3, 4, 5]:
    print(f"Hours: {h}, Predicted Score: {predict_score(h)}")
# Out:
# True
# True
# Study hour 1: predicted score = 30
# Study hour 2: predicted score = 40
# Study hour 3: predicted score = 50
# Study hour 4: predicted score = 60
# Study hour 5: predicted score = 70
# Studying... hour 1
# Studying... hour 2
# Studying... hour 3
# Studying... hour 4
# Studying... hour 5
# Hours: 1, Predicted Score: 30
# Hours: 2, Predicted Score: 40
# Hours: 3, Predicted Score: 50
# Hours: 4, Predicted Score: 60
# Hours: 5, Predicted Score: 70
